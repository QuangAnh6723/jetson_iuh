# %% [markdown]
# # Set up

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir("gdrive/MyDrive/MY_PROJECTS/")

# %%
# !mkdir yolov8

# %%
# %cd yolov8
# Out:
# /content/gdrive/MyDrive/MY_PROJECTS/yolov8

# %%
# Install YOLOv8
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 36.7/112.6 GB disk)

# %% [markdown]
# # Train YOLO

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO('yolov8n-seg.yaml')  # build a new model from scratch
model = YOLO('./v22.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='./dataset.yaml', epochs = 10)  # train the model
# results = model.train(data='coco8-seg.yaml', epochs=3)  # train the model
results = model.val()  # evaluate model performance on the validation set
# results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
# results = model.export(format='onnx')  # export the model to ONNX format
# Out:
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
